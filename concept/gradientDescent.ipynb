# %% [markdown]
# .batch gradient desent
#
#
# .stochastic gradient descent
#
#
# .mini batch gradient descent

# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("Social_Network_Ads.csv")

# %%
df.head(5)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X=df.drop(columns=["Purchased"])
y=df["Purchased"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Input

# %%
model=Sequential()
model.add(Input(shape=(2,)))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
info=model.fit(X_train,y_train,epochs=500,validation_split=0.2)
# Out:
# Epoch 1/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6367 - loss: 0.7539 - val_accuracy: 0.6562 - val_loss: 0.7553
# Epoch 2/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6641 - loss: 0.7275 - val_accuracy: 0.6875 - val_loss: 0.7292
# Epoch 3/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6797 - loss: 0.7054 - val_accuracy: 0.6875 - val_loss: 0.7032
# Epoch 4/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6875 - loss: 0.6837 - val_accuracy: 0.7031 - val_loss: 0.6813
# Epoch 5/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.6656 - val_accuracy: 0.7031 - val_loss: 0.6594
# Epoch 6/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7266 - loss: 0.6462 - val_accuracy: 0.7344 - val_loss: 0.6399
# Epoch 7/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7383 - loss: 0.6287 - val_accuracy: 0.7500 - val_loss: 0.6206
# Epoch 8/500
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(info.history['loss'],label='traing_Loss')
plt.plot(info.history['val_loss'],label='Val_loss')
plt.xlabel("epochs")
plt.title("stochastic Gradient Descent")
plt.ylabel("loss")

plt.legend()

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /Users/owner/Desktop/deep-learning/deep_learning/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_train,y,epochs=10,batch_size=250,validation_split=0.2)
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5234 - loss: 0.6767 - val_accuracy: 0.4219 - val_loss: 0.7327
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6172 - loss: 0.6611 - val_accuracy: 0.4062 - val_loss: 0.7363
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6406 - loss: 0.6539 - val_accuracy: 0.3906 - val_loss: 0.7420
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6641 - loss: 0.6444 - val_accuracy: 0.3750 - val_loss: 0.7440
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6562 - loss: 0.6419 - val_accuracy: 0.3594 - val_loss: 0.7471
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6680 - loss: 0.6375 - val_accuracy: 0.3594 - val_loss: 0.7502
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6719 - loss: 0.6333 - val_accuracy: 0.3594 - val_loss: 0.7542
# Epoch 8/10
# ...

# %%
plt.plot(history.history['loss'])
plt.title("Batch Gradient Descent")
plt.legend()
# Out:
# /var/folders/wk/485j8zms4wx1g2b_h5h_gxn80000gn/T/ipykernel_70219/661605631.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /Users/owner/Desktop/deep-learning/deep_learning/lib/python3.13/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
infomini=model.fit(X_train,y_train,epochs=500,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3359 - loss: 0.7573 - val_accuracy: 0.4062 - val_loss: 0.7402
# Epoch 2/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3477 - loss: 0.7340 - val_accuracy: 0.4375 - val_loss: 0.7216
# Epoch 3/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4023 - loss: 0.7141 - val_accuracy: 0.4375 - val_loss: 0.7050
# Epoch 4/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4375 - loss: 0.6965 - val_accuracy: 0.5781 - val_loss: 0.6904
# Epoch 5/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5352 - loss: 0.6815 - val_accuracy: 0.6250 - val_loss: 0.6770
# Epoch 6/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5938 - loss: 0.6653 - val_accuracy: 0.6406 - val_loss: 0.6642
# Epoch 7/500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6406 - loss: 0.6511 - val_accuracy: 0.7188 - val_loss: 0.6523
# Epoch 8/500
# ...

# %%
plt.plot(infomini.history['loss'],label='traing_Loss')
plt.plot(infomini.history['val_loss'],label='Val_loss')
plt.title("Batch Gradient Descent")
plt.xlabel("epochs")
plt.ylabel("loss")

plt.legend()

# %% [markdown]
# # conclusion
#
# 	•	Batch GD → Fewer updates, stable, fast convergence per epoch, but expensive per update.
# 	•	SGD → Many small updates, noisy, slower convergence per epoch, but cheaper per update.
# 	•	Mini-batch → Balanced, best in practice.
#
#     BUT for overall datapoint in batch GD we donot need more epoch as it overfit so  for correct epoch the training speed is fast and  f=the converge speed is fast in Stochastic GD
